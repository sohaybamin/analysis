# %%
import numpy as np
import matplotlib.pyplot as plt
import MDAnalysis as mda
import MDAnalysis.analysis.distances

u = mda.Universe("movie.pdb","movie.xtc")
membrane = u.select_atoms('not resname TIP3 or resname SOD or resname CLA or protein')
protein = u.select_atoms('protein')

# %%
list(protein.atoms.residues)

# %%
peptide = u.select_atoms('name CA and resid 10000')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r0.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10001')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r1.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10002')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r2.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10003')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r3.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10004')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r4.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10005')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r5.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10006')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r6.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10007')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r7.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10008')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r8.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10009')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r9.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10010')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r10.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10011')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r11.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10012')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r12.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10013')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r13.csv', a, fmt="%d", delimiter=" ")


peptide = u.select_atoms('name CA and resid 10014')
distance_COM = []
for ts in u.trajectory:
    distance_COM.append((u.trajectory.time, MDAnalysis.analysis.distances.distance_array(peptide.center_of_mass(), membrane.center_of_mass(), box=[u.dimensions[0], u.dimensions[1], u.dimensions[2], u.dimensions[3], u.dimensions[4], u.dimensions[5]])))
distance_COM = np.array(distance_COM, dtype = "object")
a=(distance_COM)
np.savetxt('r14.csv', a, fmt="%d", delimiter=" ")

# %%
r0 = np.loadtxt ('r0.csv')
r1 = np.loadtxt ('r1.csv')
r2 = np.loadtxt ('r2.csv')
r3 = np.loadtxt ('r3.csv')
r4 = np.loadtxt ('r4.csv')
r5 = np.loadtxt ('r5.csv')
r6 = np.loadtxt ('r6.csv')
r7 = np.loadtxt ('r7.csv')
r8 = np.loadtxt ('r8.csv')
r9 = np.loadtxt ('r9.csv')
r10 = np.loadtxt ('r10.csv')
r11 = np.loadtxt ('r11.csv')
r12 = np.loadtxt ('r12.csv')
r13 = np.loadtxt ('r13.csv')
r14 = np.loadtxt ('r14.csv')


r0_e=r0[0:].T[1]
r1_e=r1[0:].T[1]
r2_e=r2[0:].T[1]
r3_e=r3[0:].T[1]
r4_e=r4[0:].T[1]
r5_e=r5[0:].T[1]
r6_e=r6[0:].T[1]
r7_e=r7[0:].T[1]
r8_e=r8[0:].T[1]
r9_e=r9[0:].T[1]
r10_e=r10[0:].T[1]
r11_e=r11[0:].T[1]
r12_e=r12[0:].T[1]
r13_e=r13[0:].T[1]
r14_e=r14[0:].T[1]

# %%
fig, axs = plt.subplots(5, 3,sharex=True, sharey=True)

fig.suptitle('Title', size='15') ###########<---------------- Rename this

plt.setp(axs, xticks=[0, 50, 100, 150, 200], xticklabels=['0','25000','50000','75000','100000'])

fig.add_subplot(111, frameon=False)

plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel("Time (ps)", size='12.5')
plt.ylabel("Area (nm)", size='12.5')
plt.rcParams["axes.grid"] = False
fig.tight_layout()



axs[0, 0].plot(r0_e, linewidth=1.5)
axs[0, 0].set_title('Residue 0',size='12.5')

axs[0, 1].plot(r1_e, linewidth=1.5)
axs[0, 1].set_title('Residue 1',size='12.5')


axs[0, 2].plot(r2_e, linewidth=1.5)
axs[0, 2].set_title('Residue 2',size='12.5')


axs[1, 0].plot(r3_e, linewidth=1.5)
axs[1, 0].set_title('Residue 3',size='12.5')


axs[1, 1].plot(r4_e, linewidth=1.5)
axs[1, 1].set_title('Residue 4',size='12.5')


axs[1, 2].plot(r5_e, linewidth=1.5)
axs[1, 2].set_title('Residue 5',size='12.5')


axs[2, 0].plot(r6_e, linewidth=1.5)
axs[2, 0].set_title('Residue 6',size='12.5')


axs[2, 1].plot(r7_e, linewidth=1.5)
axs[2, 1].set_title('Residue 7',size='12.5')


axs[2, 2].plot(r8_e, linewidth=1.5)
axs[2, 2].set_title('Residue 8',size='12.5')


axs[3, 0].plot(r9_e, linewidth=1.5)
axs[3, 0].set_title('Residue 9',size='12.5')


axs[3, 1].plot(r10_e, linewidth=1.5)
axs[3, 1].set_title('Residue 10',size='12.5')


axs[3, 2].plot(r11_e, linewidth=1.5)
axs[3, 2].set_title('Residue 11',size='12.5')


axs[4, 0].plot(r12_e, linewidth=1.5)
axs[4, 0].set_title('Residue 12',size='12.5')


axs[4, 1].plot(r13_e, linewidth=1.5)
axs[4, 1].set_title('Residue 13',size='12.5')


axs[4, 2].plot(r14_e, linewidth=1.5)
axs[4, 2].set_title('Residue 14',size='12.5')


fig.tight_layout()
plt.rcParams["figure.figsize"] = (20,15)

plt.savefig(('all_res_absorption_subplots.png'), format='png', dpi=900)
